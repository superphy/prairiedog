# %%
import pickle

# %%
df = pickle.load(open('../samples/public_mic_class_dataframe.pkl', 'rb'))

# %%
df
# Out:
#                   AMP        AMC        FOX        CRO       TIO        GEN  \
# run
# SRR2407707   <=1.0000   <=1.0000     4.0000   <=0.2500    1.0000     0.5000
# SRR2407694     2.0000   <=1.0000     2.0000   <=0.2500    1.0000     1.0000
# SRR2407599   <=1.0000   <=1.0000     2.0000   <=0.2500    1.0000     0.5000
# SRR2407704     2.0000   <=1.0000     8.0000   <=0.2500    2.0000     0.5000
# SRR2407697   <=1.0000   <=1.0000     4.0000   <=0.2500    1.0000     1.0000
# SRR2407691     2.0000     2.0000     4.0000   <=0.2500    1.0000     0.5000
# SRR2407706   <=1.0000   <=1.0000     4.0000   <=0.2500    1.0000     0.5000
# SRR2407712   <=1.0000   <=1.0000     4.0000   <=0.2500    2.0000     0.5000
# SRR2407653   <=1.0000   <=1.0000     2.0000   <=0.2500    1.0000     0.5000
# SRR2407590   <=1.0000   <=1.0000     2.0000   <=0.2500    1.0000     0.5000
# SRR2407670   <=1.0000   <=1.0000     2.0000   <=0.2500    1.0000     0.5000
# ...
